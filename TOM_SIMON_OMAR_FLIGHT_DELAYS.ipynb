# %%
# General options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)

colors = {
    "Baseline": "#1f77b4",      # bleu
    "Class Weight": "#ff7f0e",  # orange
    "SMOTE": "#2ca02c",         # vert
    "LogReg": "#d62728",        # rouge
    "DecisionTree": "#9467bd",  # violet
    "RandomForest": "#8c564b",  # marron
    "XGBoost": "#17becf",       # cyan
}


warnings.filterwarnings('ignore')

HTML('''
<script>
    code_show=true; 
    function code_toggle() {
        if (code_show){
        $('div.input').hide();
        } else {
        $('div.input').show();
        }
        code_show = !code_show
    } 
    $( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Show/Hide Code"></form>
''')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # General options
# ----> 2 pd.set_option('display.max_columns', None)
#       3 pd.set_option('display.max_rows', 100)
#       4 pd.set_option('display.width', None)
#
# NameError: name 'pd' is not defined

# %%
# Load datasets
flights_df = pd.read_csv("flights.csv", low_memory=False)
airlines_df = pd.read_csv("airlines.csv")
airports_df = pd.read_csv("airports.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load datasets
# ----> 2 flights_df = pd.read_csv("flights.csv", low_memory=False)
#       3 airlines_df = pd.read_csv("airlines.csv")
#       4 airports_df = pd.read_csv("airports.csv")
#
# NameError: name 'pd' is not defined
